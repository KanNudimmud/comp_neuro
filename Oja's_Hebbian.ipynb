# %% [markdown]
# # Oja’s hebbian learning rule

# %%
import neurodynex3.ojas_rule.oja as oja

# %%
cloud = oja.make_cloud()  # generate data points
wcourse = oja.learn(cloud)  # learn weights and return timecourse

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

cloud = oja.make_cloud(n=200, ratio=.3, angle=60)
wcourse = oja.learn(cloud, initial_angle=-20, eta=0.04)
plt.scatter(cloud[:, 0], cloud[:, 1], marker=".", alpha=.2)
plt.plot(wcourse[-1, 0], wcourse[-1, 1], "or", markersize=10)
plt.axis('equal')
plt.figure()
plt.plot(wcourse[:, 0], "g")
plt.plot(wcourse[:, 1], "b")
print("The final weight vector w is: ({},{})".format(wcourse[-1,0],wcourse[-1,1]))
# Out:
# The final weight vector w is: (0.539479784232956,0.8435566857352573)

# %% [markdown]
# ## Exercise: getting started

# %% [markdown]
# ### Question: The norm of the weights

# %%
# Run the script with a large learning rate eta = 0.2. 
cloud = oja.make_cloud(n=200, ratio=.3, angle=60)
wcourse = oja.learn(cloud, initial_angle=-20, eta=0.2)
plt.scatter(cloud[:, 0], cloud[:, 1], marker=".", alpha=.2)
plt.plot(wcourse[-1, 0], wcourse[-1, 1], "or", markersize=10)
plt.axis('equal')
plt.figure()
plt.plot(wcourse[:, 0], "g")
plt.plot(wcourse[:, 1], "b")
print("The final weight vector w is: ({},{})".format(wcourse[-1,0],wcourse[-1,1]))
# Out:
# The final weight vector w is: (0.6511797133842968,0.7657608432627447)

# %% [markdown]
# ## Exercise: Circular data

# %%
# Run the script with ratio of 1. 
cloud = oja.make_cloud(n=200, ratio=1, angle=60)
wcourse = oja.learn(cloud, initial_angle=-20, eta=0.2)
plt.scatter(cloud[:, 0], cloud[:, 1], marker=".", alpha=.2)
plt.plot(wcourse[-1, 0], wcourse[-1, 1], "or", markersize=10)
plt.axis('equal')
plt.figure()
plt.plot(wcourse[:, 0], "g")
plt.plot(wcourse[:, 1], "b")
print("The final weight vector w is: ({},{})".format(wcourse[-1,0],wcourse[-1,1]))
# Out:
# The final weight vector w is: (0.07916798264328365,-0.9943674521257185)

# %% [markdown]
# ## Exercise: What is the neuron leaning?

# %%
# elongated elliptic data cloud (e.g. ratio=0.3)
cloud = oja.make_cloud(n=200, ratio=0.3, angle=60)
wcourse = oja.learn(cloud, initial_angle=-20, eta=0.2)
plt.scatter(cloud[:, 0], cloud[:, 1], marker=".", alpha=.2)
plt.plot(wcourse[-1, 0], wcourse[-1, 1], "or", markersize=10)
plt.axis('equal')
plt.figure()
plt.plot(wcourse[:, 0], "g")
plt.plot(wcourse[:, 1], "b")
print("The final weight vector w is: ({},{})".format(wcourse[-1,0],wcourse[-1,1]))
# Out:
# The final weight vector w is: (0.47629115891133683,0.8786252777896078)

# %% [markdown]
# ## Exercise: Non-centered data

# %%
# use cloud = (3,5) + oja.make_cloud(n=1000, ratio=.4, angle=-45), which centers the data around (3,5).
# elongated elliptic data cloud (e.g. ratio=0.3)
cloud = oja.make_cloud(n=1000, ratio=0.4, angle=45)
wcourse = oja.learn(cloud, initial_angle=-20, eta=0.2)
plt.scatter(cloud[:, 0], cloud[:, 1], marker=".", alpha=.2)
plt.plot(wcourse[-1, 0], wcourse[-1, 1], "or", markersize=10)
plt.axis('equal')
plt.figure()
plt.plot(wcourse[:, 0], "g")
plt.plot(wcourse[:, 1], "b")
print("The final weight vector w is: ({},{})".format(wcourse[-1,0],wcourse[-1,1]))
# Out:
# The final weight vector w is: (0.4933744126291434,0.847949751911391)
